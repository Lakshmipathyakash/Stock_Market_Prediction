# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshmipathyakash/Stock_Market_Prediction/blob/main/stock_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf

# %%
symbol = "^NSEI"

# %%
nifty50 = yf.Ticker(symbol)

# %%
hist = nifty50.history(period="5y")

# %%
hist
# Out:
#                                    Open          High           Low  \
# Date
# 2021-02-02 00:00:00+05:30  14481.099609  14731.700195  14469.150391
# 2021-02-03 00:00:00+05:30  14754.900391  14868.849609  14574.150391
# 2021-02-04 00:00:00+05:30  14789.049805  14913.700195  14714.750000
# 2021-02-05 00:00:00+05:30  14952.599609  15014.650391  14864.750000
# 2021-02-08 00:00:00+05:30  15064.299805  15159.900391  15041.049805
# ...                                 ...           ...           ...
# 2026-01-27 00:00:00+05:30  25063.349609  25246.650391  24932.550781
# 2026-01-28 00:00:00+05:30  25258.849609  25372.099609  25187.650391
# 2026-01-29 00:00:00+05:30  25345.000000  25458.150391  25159.800781
# 2026-01-30 00:00:00+05:30  25247.550781  25370.699219  25213.650391
# 2026-02-02 00:00:00+05:30  25247.550781  25108.099609  24679.400391
#
#                                   Close  Volume  Dividends  Stock Splits
# Date
# ...

# %%
nifty_next_50 = yf.Ticker("^NSEI")

# %%
nifty_next_50 = nifty_next_50.history(period = "max")

# %%
nifty_next_50
# Out:
#                                    Open          High           Low  \
# Date
# 2007-09-17 00:00:00+05:30   4518.450195   4549.049805   4482.850098
# 2007-09-18 00:00:00+05:30   4494.100098   4551.799805   4481.549805
# 2007-09-19 00:00:00+05:30   4550.250000   4739.000000   4550.250000
# 2007-09-20 00:00:00+05:30   4734.850098   4760.850098   4721.149902
# 2007-09-21 00:00:00+05:30   4752.950195   4855.700195   4733.700195
# ...                                 ...           ...           ...
# 2026-01-27 00:00:00+05:30  25063.349609  25246.650391  24932.550781
# 2026-01-28 00:00:00+05:30  25258.849609  25372.099609  25187.650391
# 2026-01-29 00:00:00+05:30  25345.000000  25458.150391  25159.800781
# 2026-01-30 00:00:00+05:30  25247.550781  25370.699219  25213.650391
# 2026-02-02 00:00:00+05:30  25247.550781  25108.099609  24679.400391
#
#                                   Close  Volume  Dividends  Stock Splits
# Date
# ...

# %%
nifty_next_50.index
# Out:
# DatetimeIndex(['2007-09-17 00:00:00+05:30', '2007-09-18 00:00:00+05:30',
#                '2007-09-19 00:00:00+05:30', '2007-09-20 00:00:00+05:30',
#                '2007-09-21 00:00:00+05:30', '2007-09-24 00:00:00+05:30',
#                '2007-09-25 00:00:00+05:30', '2007-09-26 00:00:00+05:30',
#                '2007-09-27 00:00:00+05:30', '2007-09-28 00:00:00+05:30',
#                ...
#                '2026-01-19 00:00:00+05:30', '2026-01-20 00:00:00+05:30',
#                '2026-01-21 00:00:00+05:30', '2026-01-22 00:00:00+05:30',
#                '2026-01-23 00:00:00+05:30', '2026-01-27 00:00:00+05:30',
#                '2026-01-28 00:00:00+05:30', '2026-01-29 00:00:00+05:30',
#                '2026-01-30 00:00:00+05:30', '2026-02-02 00:00:00+05:30'],
#               dtype='datetime64[ns, Asia/Kolkata]', name='Date', length=4508, freq=None)

# %%
nifty_next_50.plot.line(y="Close", use_index = True)
# Out:
# <Axes: xlabel='Date'>

# %%
del nifty_next_50["Dividends"]
del nifty_next_50["Stock Splits"]

# %%
nifty_next_50["Tomorrow"] = nifty_next_50["Close"].shift(-1)

# %%
nifty_next_50
# Out:
#                                    Open          High           Low  \
# Date
# 2007-09-17 00:00:00+05:30   4518.450195   4549.049805   4482.850098
# 2007-09-18 00:00:00+05:30   4494.100098   4551.799805   4481.549805
# 2007-09-19 00:00:00+05:30   4550.250000   4739.000000   4550.250000
# 2007-09-20 00:00:00+05:30   4734.850098   4760.850098   4721.149902
# 2007-09-21 00:00:00+05:30   4752.950195   4855.700195   4733.700195
# ...                                 ...           ...           ...
# 2026-01-27 00:00:00+05:30  25063.349609  25246.650391  24932.550781
# 2026-01-28 00:00:00+05:30  25258.849609  25372.099609  25187.650391
# 2026-01-29 00:00:00+05:30  25345.000000  25458.150391  25159.800781
# 2026-01-30 00:00:00+05:30  25247.550781  25370.699219  25213.650391
# 2026-02-02 00:00:00+05:30  25247.550781  25108.099609  24679.400391
#
#                                   Close  Volume      Tomorrow
# Date
# 2007-09-17 00:00:00+05:30   4494.649902       0   4546.200195
# ...

# %%
nifty_next_50["Target"] = (nifty_next_50["Tomorrow"] > nifty_next_50["Close"]).astype(int)

# %%
nifty_next_50
# Out:
#                                    Open          High           Low  \
# Date
# 2007-09-17 00:00:00+05:30   4518.450195   4549.049805   4482.850098
# 2007-09-18 00:00:00+05:30   4494.100098   4551.799805   4481.549805
# 2007-09-19 00:00:00+05:30   4550.250000   4739.000000   4550.250000
# 2007-09-20 00:00:00+05:30   4734.850098   4760.850098   4721.149902
# 2007-09-21 00:00:00+05:30   4752.950195   4855.700195   4733.700195
# ...                                 ...           ...           ...
# 2026-01-27 00:00:00+05:30  25063.349609  25246.650391  24932.550781
# 2026-01-28 00:00:00+05:30  25258.849609  25372.099609  25187.650391
# 2026-01-29 00:00:00+05:30  25345.000000  25458.150391  25159.800781
# 2026-01-30 00:00:00+05:30  25247.550781  25370.699219  25213.650391
# 2026-02-02 00:00:00+05:30  25247.550781  25108.099609  24679.400391
#
#                                   Close  Volume      Tomorrow  Target
# Date
# ...

# %%
nifty_next_50 = nifty_next_50.loc["2016-01-01":].copy()
nifty_next_50
# Out:
#                                    Open          High           Low  \
# Date
# 2016-01-04 00:00:00+05:30   7924.549805   7937.549805   7781.100098
# 2016-01-05 00:00:00+05:30   7828.399902   7831.200195   7763.250000
# 2016-01-06 00:00:00+05:30   7788.049805   7800.950195   7721.200195
# 2016-01-07 00:00:00+05:30   7673.350098   7674.950195   7556.600098
# 2016-01-08 00:00:00+05:30   7611.649902   7634.100098   7581.049805
# ...                                 ...           ...           ...
# 2026-01-27 00:00:00+05:30  25063.349609  25246.650391  24932.550781
# 2026-01-28 00:00:00+05:30  25258.849609  25372.099609  25187.650391
# 2026-01-29 00:00:00+05:30  25345.000000  25458.150391  25159.800781
# 2026-01-30 00:00:00+05:30  25247.550781  25370.699219  25213.650391
# 2026-02-02 00:00:00+05:30  25247.550781  25108.099609  24679.400391
#
#                                   Close  Volume      Tomorrow  Target
# Date
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = nifty_next_50.iloc[:-200]
test = nifty_next_50.iloc[-200:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score

preds = model.predict(test[predictors])

# %%
import pandas as pd
preds =pd.Series(preds, index = test.index)

# %%
preds
# Out:
# Date
# 2025-04-15 00:00:00+05:30    1
# 2025-04-16 00:00:00+05:30    1
# 2025-04-17 00:00:00+05:30    0
# 2025-04-21 00:00:00+05:30    0
# 2025-04-22 00:00:00+05:30    0
#                             ..
# 2026-01-27 00:00:00+05:30    1
# 2026-01-28 00:00:00+05:30    1
# 2026-01-29 00:00:00+05:30    1
# 2026-01-30 00:00:00+05:30    0
# 2026-02-02 00:00:00+05:30    0
# Length: 200, dtype: int64

# %%
precision_score(test['Target'], preds)
# Out:
# 0.5495495495495496

# %%
combined = pd.concat([test["Target"], preds], axis = 1)

# %%
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def predict(train, test, predictors, model):
  model.fit(train[predictors], train['Target'])
  preds = model.predict(test[predictors])
  preds = pd.Series(preds, index = test.index, name = "Predictions")
  combined = pd.concat([test["Target"], preds], axis = 1)
  return combined

# %%
def backtest(data, model, predictors, start=738, step=246):
    all_predictions = []

    # print(f"Data length: {data.shape[0]}, Start: {start}, Step: {step}")  # Debug print

    for i in range(start, data.shape[0], step):
        # print(f"Processing slice: {i}:{i+step}")  # Debug print
        train = data.iloc[i:(i+step)].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        # print(f"Predictions shape: {predictions.shape}")  # Debug print
        all_predictions.append(predictions)

    # if not all_predictions:  # Check if list is empty
    #     print("No predictions were made.")
    #     return pd.DataFrame()  # Return empty DataFrame or handle appropriately

    return pd.concat(all_predictions)

# %%
# print(len(nifty_next_50))

# %%
predictions = backtest(nifty_next_50, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 1    1243
# 0     504
# Name: count, dtype: int64

# %%
precision_score(predictions['Target'], predictions['Predictions'])
# Out:
# 0.6532582461786002

# %%
predictions['Target'].value_counts()/predictions.shape[0]
# Out:
# Target
# 1    0.540927
# 0    0.459073
# Name: count, dtype: float64

# %%
horizons = [2,5,6,246,984]
new_predictors = []

for horizon in horizons:
  rolling_averages = nifty_next_50.rolling(horizon).mean()

  ratio_column = f"Close_Ratio_{horizon}"
  nifty_next_50[ratio_column] = nifty_next_50["Close"] / rolling_averages["Close"]

  trend_column = f"Trend_{horizon}"
  nifty_next_50[trend_column] = nifty_next_50['Target'].rolling(horizon).sum()

  new_predictors+= [ratio_column, trend_column]

# %%
nifty_next_50 = nifty_next_50.dropna(subset=nifty_next_50.columns[nifty_next_50.columns != "Tomorrow"])

# %%
nifty_next_50
# Out:
#                                    Open          High           Low  \
# Date
# 2020-01-08 00:00:00+05:30  11939.099609  12044.950195  11929.599609
# 2020-01-09 00:00:00+05:30  12153.150391  12224.049805  12132.549805
# 2020-01-10 00:00:00+05:30  12271.000000  12311.200195  12213.200195
# 2020-01-13 00:00:00+05:30  12296.700195  12337.750000  12285.799805
# 2020-01-14 00:00:00+05:30  12333.099609  12374.250000  12308.700195
# ...                                 ...           ...           ...
# 2026-01-27 00:00:00+05:30  25063.349609  25246.650391  24932.550781
# 2026-01-28 00:00:00+05:30  25258.849609  25372.099609  25187.650391
# 2026-01-29 00:00:00+05:30  25345.000000  25458.150391  25159.800781
# 2026-01-30 00:00:00+05:30  25247.550781  25370.699219  25213.650391
# 2026-02-02 00:00:00+05:30  25247.550781  25108.099609  24679.400391
#
#                                   Close  Volume      Tomorrow  Target  \
# Date
# ...

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split= 10, random_state=1)

# %%
def predict(train, test, predictors, model):
  model.fit(train[predictors], train['Target'])
  preds = model.predict(test[predictors])
  preds[preds>=.6] = 1
  preds[preds< .6] = 0
  preds = pd.Series(preds, index = test.index, name = "Predictions")
  combined = pd.concat([test["Target"], preds], axis = 1)
  return combined

# %%
predictions = backtest(nifty_next_50, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 1    408
# 0    356
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 1.0

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.536649
# 0    0.463351
# Name: count, dtype: float64

# %%
predictions
# Out:
#                            Target  Predictions
# Date
# 2022-12-28 00:00:00+05:30       1            1
# 2022-12-29 00:00:00+05:30       0            0
# 2022-12-30 00:00:00+05:30       1            1
# 2023-01-02 00:00:00+05:30       1            1
# 2023-01-03 00:00:00+05:30       0            0
# ...                           ...          ...
# 2026-01-27 00:00:00+05:30       1            1
# 2026-01-28 00:00:00+05:30       1            1
# 2026-01-29 00:00:00+05:30       0            0
# 2026-01-30 00:00:00+05:30       0            0
# 2026-02-02 00:00:00+05:30       0            0
#
# [764 rows x 2 columns]
